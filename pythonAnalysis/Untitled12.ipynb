# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import csv
from selenium import webdriver

data=pd.read_csv('KC_KOBIS_BOX_OFFIC_MOVIE_INFO_2020.csv', index_col=0)
data
data_all=data[data['GRAD_NM'] != '청소년관람불가']
data_all
# Out:
#           MOVIE_NM  DRCTR_NM      MAKR_NM INCME_CMPNY_NM       DISTB_CMPNY_NM  \
# NO
# 1          남산의 부장들       우민호  (주)하이브미디어코프            NaN               (주)쇼박스
# 2      다만 악에서 구하소서       홍원찬  (주)하이브미디어코프            NaN            (주)씨제이이엔엠
# 3               반도       연상호   (주)영화사레드피터            NaN  (주)넥스트엔터테인먼트월드(NEW)
# 4              히트맨       최원섭   베리굿스튜디오(주)            NaN    롯데컬처웍스(주)롯데엔터테인먼트
# 5               테넷  크리스토퍼 놀란          NaN  워너브러더스 코리아(주)        워너브러더스 코리아(주)
# ...            ...       ...          ...            ...                  ...
# 1921       학교는 끝났다       NaN          NaN            NaN            주식회사 플릭스코
# 1933   햄릿: 죽느냐 사느냐       NaN          NaN            NaN          (주)영화사 안다미로
# 1935          헤리티지       NaN          NaN    (주)영화사 안다미로          (주)영화사 안다미로
# 1936         헤븐퀘스트       NaN          NaN       (주)스토리제이             (주)스토리제이
# 1976  3022: 지구 대폭발     존 슈이츠          NaN    (주)더그레이트컴퍼니          (주)더그레이트컴퍼니
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-be99a8fd4a0a> in <module>
# ----> 1 rea = csv.reader(data_all)
#
# NameError: name 'csv' is not defined
