# %%
from scipy import stats
import pandas as pd
import seaborn as sns
x=stats.norm.rvs(size=30)
e=stats.norm.rvs(scale=0.2, size=30)
y=x+e
df = pd.DataFrame([x,y]).T
sns.scatterplot(data=df, x=0, y=1)
print(stats.pearsonr(x,y))
# Out:
# PearsonRResult(statistic=0.9680889777697576, pvalue=2.287705219005412e-18)

# %%
sns.scatterplot(data=df, x=0, y=1)
print(stats.pearsonr(x,y))
print(stats.spearmanr(x,y))
# Out:
# PearsonRResult(statistic=0.9680889777697576, pvalue=2.287705219005412e-18)
# SpearmanrResult(correlation=0.9581757508342603, pvalue=9.498913999882393e-17)
